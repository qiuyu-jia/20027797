# %% [markdown]
# <a href="https://colab.research.google.com/github/qiuyu-jia/20027797/blob/main/text1easyNST_on_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Clone the repository
# The repo will be clone into the folder 'ComputerVision'. If this folder already exists, it is removed first with the call to '!rm -r ComputerVision NeuralStyleTransfer'. Having cloned the repo we copy the 'NeuralStyleTransfe'r folder to the current working directory.

# %%
# %tensorflow_version 1.x
# !rm -r ComputerVision NeuralStyleTransfer

# !git clone https://github.com/ldfrancis/ComputerVision.git
  
# !cp -r ComputerVision/NeuralStyleTransfer .
# Out:
# Cloning into 'ComputerVision'...
# remote: Enumerating objects: 699, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 699 (delta 2), reused 0 (delta 0), pack-reused 691
# Receiving objects: 100% (699/699), 32.20 MiB | 11.07 MiB/s, done.
# Resolving deltas: 100% (319/319), done.

# %% [markdown]
# ## Upload
# We upload 2 images from our local machine. One will act as the content image and the other will be the style image. Take note of the name of the uploaded image (e.g starrynight.jpg)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9f2a1523-4081-47fc-b324-376f5cea719a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f2a1523-4081-47fc-b324-376f5cea719a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving content1.jpg to content1 (1).jpg
# ...

# %% [markdown]
# ## Settings
# The next thing to do after uploading the style and content image is to set them. The variables, CONTENT_IMAGE and STYLE_IMAGE hold the name of the content image and style image respectively. Change the value of the variables to the names of the images you uploaded.
#
# ---
#
# The style image and content image must have the same dimension (i.e same width and heigth). Set the widht and heigth of the images in the variables IMAGE_WIDTH and IMAGE_HEIGHT BY changing their values.

# %%
CONTENT_IMAGE = "content1.jpg" 
STYLE_IMAGE = "style1.jpg"

IMAGE_HEIGHT = 300
IMAGE_WIDTH = 400

ITERATION = 200

# %% [markdown]
# The code below sets the path to the content  image and style image

# %%
path_to_content_image = "/content/"+CONTENT_IMAGE
path_to_style_image = "/content/"+STYLE_IMAGE

# %% [markdown]
# ## View the images that were uploaded

# %%
import matplotlib.pyplot as plt
c_image = plt.imread(path_to_content_image)
s_image = plt.imread(path_to_style_image)

# %%
print("Content Image of size (height, width) => {0}".format(c_image.shape[:-1]))
plt.imshow(c_image)
# Out:
# Content Image of size (height, width) => (1080, 1080)

# %%
print("Style Image of size (height, width) => {0}".format(s_image.shape[:-1]))
plt.imshow(s_image)
# Out:
# Style Image of size (height, width) => (1080, 1080)

# %% [markdown]
# With all settings intact, we import the implementNTS module, set the image dimension and the run the style transfer to generate the mixed image.

# %%
from NeuralStyleTransfer import implementNTS as NST

NST.setImageDim(IMAGE_WIDTH,IMAGE_HEIGHT)

NST.run(ITERATION, style_image=path_to_style_image, content_image=path_to_content_image)
# Out:
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:318: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# downloading...
# *done*
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:204: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:333: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:355: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %% [markdown]
# In the code implementation, the mixed image of [content and style images] is saved after every 100 iterations and the final image is saved as 'generated_image.jpg'. We list all saved images below.

# %%
# !ls NeuralStyleTransfer/output/
# Out:
# 100.jpg  200.jpg  generated_image.jpg  oimage

# %% [markdown]
# ## View generated image

# %%
generated_image_path = "/content/NeuralStyleTransfer/output/generated_image.jpg"
image = plt.imread(generated_image_path)
plt.imshow(image)

# %% [markdown]
# # The final generated image can be downloaded by running the code cell below

# %%
files.download("NeuralStyleTransfer/output/generated_image.jpg")
